# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | narsaq
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | atasu
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | mirnyy
# Processing Record 15 of Set 1 | beringovskiy
# Processing Record 16 of Set 1 | mar del plata
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | tessalit
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | coquimbo
# Processing Record 24 of Set 1 | novita
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | chara
# Processing Record 28 of Set 1 | bonavista
# Processing Record 29 of Set 1 | ornskoldsvik
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 1 | vila velha
# Processing Record 34 of Set 1 | saint george
# Processing Record 35 of Set 1 | cabrero
# Processing Record 36 of Set 1 | touros
# Processing Record 37 of Set 1 | airai
# Processing Record 38 of Set 1 | hunchun
# Processing Record 39 of Set 1 | toktogul
# Processing Record 40 of Set 1 | casper
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | ust-ilimsk
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | san policarpo
# Processing Record 46 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | san patricio
# Processing Record 49 of Set 1 | van
# Processing Record 50 of Set 1 | chumikan
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | chuy
# Processing Record 3 of Set 2 | nelson bay
# Processing Record 4 of Set 2 | naze
# Processing Record 5 of Set 2 | isangel
# Processing Record 6 of Set 2 | rumoi
# Processing Record 7 of Set 2 | nuzvid
# Processing Record 8 of Set 2 | tarauaca
# Processing Record 9 of Set 2 | waddan
# Processing Record 10 of Set 2 | ribeira grande
# Processing Record 11 of Set 2 | te karaka
# Processing Record 12 of Set 2 | suluktu
# Processing Record 13 of Set 2 | jawhar
# Processing Record 14 of Set 2 | qaqortoq
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | trofors
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | abu zabad
# Processing Record 21 of Set 2 | yuancheng
# Processing Record 22 of Set 2 | gazanjyk
# Processing Record 23 of Set 2 | tateyama
# Processing Record 24 of Set 2 | vostok
# Processing Record 25 of Set 2 | luderitz
# Processing Record 26 of Set 2 | miranorte
# City not found. Skipping...
# Processing Record 27 of Set 2 | marawi
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | kaitangata
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | hamilton
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | tevaitoa
# Processing Record 35 of Set 2 | avarua
# Processing Record 36 of Set 2 | laguna
# Processing Record 37 of Set 2 | roald
# Processing Record 38 of Set 2 | puerto del rosario
# Processing Record 39 of Set 2 | ossora
# Processing Record 40 of Set 2 | murashi
# Processing Record 41 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 2 | merauke
# Processing Record 43 of Set 2 | nanortalik
# Processing Record 44 of Set 2 | la ronge
# Processing Record 45 of Set 2 | saint-augustin
# Processing Record 46 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 2 | iqaluit
# Processing Record 48 of Set 2 | bluff
# Processing Record 49 of Set 2 | cape town
# Processing Record 50 of Set 2 | mount isa
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | bandarbeyla
# Processing Record 3 of Set 3 | skjervoy
# Processing Record 4 of Set 3 | mogadishu
# Processing Record 5 of Set 3 | qaanaaq
# Processing Record 6 of Set 3 | tazovskiy
# Processing Record 7 of Set 3 | esperance
# Processing Record 8 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | saldanha
# Processing Record 11 of Set 3 | agua dulce
# Processing Record 12 of Set 3 | vanavara
# Processing Record 13 of Set 3 | romans-sur-isere
# Processing Record 14 of Set 3 | lompoc
# Processing Record 15 of Set 3 | sivaki
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | sao joao batista
# Processing Record 18 of Set 3 | banmo
# City not found. Skipping...
# Processing Record 19 of Set 3 | tuktoyaktuk
# Processing Record 20 of Set 3 | hambantota
# Processing Record 21 of Set 3 | kareli
# Processing Record 22 of Set 3 | tura
# Processing Record 23 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 3 | yeppoon
# Processing Record 25 of Set 3 | arlit
# Processing Record 26 of Set 3 | summerside
# Processing Record 27 of Set 3 | charlestown
# Processing Record 28 of Set 3 | eberswalde
# Processing Record 29 of Set 3 | bengkulu
# Processing Record 30 of Set 3 | amapa
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | yantzaza
# Processing Record 33 of Set 3 | te anau
# Processing Record 34 of Set 3 | butaritari
# Processing Record 35 of Set 3 | cherskiy
# Processing Record 36 of Set 3 | alofi
# Processing Record 37 of Set 3 | vardo
# Processing Record 38 of Set 3 | dori
# Processing Record 39 of Set 3 | talnakh
# Processing Record 40 of Set 3 | simao
# Processing Record 41 of Set 3 | port alfred
# Processing Record 42 of Set 3 | manuk mangkaw
# Processing Record 43 of Set 3 | georgetown
# Processing Record 44 of Set 3 | kalmunai
# Processing Record 45 of Set 3 | ust-ishim
# Processing Record 46 of Set 3 | kampene
# Processing Record 47 of Set 3 | montrose
# Processing Record 48 of Set 3 | henties bay
# Processing Record 49 of Set 3 | flinders
# Processing Record 50 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 4 | osoyoos
# Processing Record 2 of Set 4 | sadasivpet
# Processing Record 3 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 4 | clyde river
# Processing Record 5 of Set 4 | nuuk
# Processing Record 6 of Set 4 | batagay-alyta
# Processing Record 7 of Set 4 | port hardy
# Processing Record 8 of Set 4 | lyubytino
# Processing Record 9 of Set 4 | khatanga
# Processing Record 10 of Set 4 | meulaboh
# Processing Record 11 of Set 4 | kampot
# Processing Record 12 of Set 4 | cockburn town
# Processing Record 13 of Set 4 | faya
# Processing Record 14 of Set 4 | cidreira
# Processing Record 15 of Set 4 | belyy yar
# Processing Record 16 of Set 4 | areosa
# Processing Record 17 of Set 4 | bayji
# Processing Record 18 of Set 4 | najran
# Processing Record 19 of Set 4 | waingapu
# Processing Record 20 of Set 4 | lorengau
# Processing Record 21 of Set 4 | north platte
# Processing Record 22 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 4 | salinas
# Processing Record 24 of Set 4 | pazardzik
# City not found. Skipping...
# Processing Record 25 of Set 4 | zhuozhou
# City not found. Skipping...
# Processing Record 26 of Set 4 | bud
# Processing Record 27 of Set 4 | sompeta
# Processing Record 28 of Set 4 | lima
# Processing Record 29 of Set 4 | clarksville
# Processing Record 30 of Set 4 | dingle
# Processing Record 31 of Set 4 | vao
# Processing Record 32 of Set 4 | nouadhibou
# Processing Record 33 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 4 | byron bay
# Processing Record 35 of Set 4 | geraldton
# Processing Record 36 of Set 4 | barra patuca
# Processing Record 37 of Set 4 | nishihara
# Processing Record 38 of Set 4 | longyearbyen
# Processing Record 39 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 4 | gazojak
# Processing Record 41 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 42 of Set 4 | manokwari
# Processing Record 43 of Set 4 | sitka
# Processing Record 44 of Set 4 | lokosovo
# Processing Record 45 of Set 4 | zonguldak
# Processing Record 46 of Set 4 | katsuura
# Processing Record 47 of Set 4 | norman wells
# Processing Record 48 of Set 4 | sola
# Processing Record 49 of Set 4 | broken hill
# Processing Record 50 of Set 4 | isla aguada
# Processing Record 1 of Set 5 | constitucion
# Processing Record 2 of Set 5 | moose factory
# Processing Record 3 of Set 5 | rocha
# Processing Record 4 of Set 5 | bulungu
# Processing Record 5 of Set 5 | ustyuzhna
# Processing Record 6 of Set 5 | kanye
# Processing Record 7 of Set 5 | upernavik
# Processing Record 8 of Set 5 | beloha
# Processing Record 9 of Set 5 | seoul
# Processing Record 10 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 5 | harrai
# Processing Record 12 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 5 | muroto
# Processing Record 14 of Set 5 | warrnambool
# Processing Record 15 of Set 5 | aklavik
# Processing Record 16 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 5 | faanui
# Processing Record 18 of Set 5 | tuatapere
# Processing Record 19 of Set 5 | otautau
# Processing Record 20 of Set 5 | jingdezhen
# Processing Record 21 of Set 5 | tilichiki
# Processing Record 22 of Set 5 | guerrero negro
# Processing Record 23 of Set 5 | miyako
# Processing Record 24 of Set 5 | manggar
# Processing Record 25 of Set 5 | sindhnur
# Processing Record 26 of Set 5 | yulara
# Processing Record 27 of Set 5 | houma
# Processing Record 28 of Set 5 | san quintin
# Processing Record 29 of Set 5 | matara
# Processing Record 30 of Set 5 | araouane
# Processing Record 31 of Set 5 | pevek
# Processing Record 32 of Set 5 | paamiut
# Processing Record 33 of Set 5 | berlevag
# Processing Record 34 of Set 5 | aswan
# Processing Record 35 of Set 5 | grushevskaya
# Processing Record 36 of Set 5 | fairbanks
# Processing Record 37 of Set 5 | komsomolskiy
# Processing Record 38 of Set 5 | onega
# Processing Record 39 of Set 5 | broome
# Processing Record 40 of Set 5 | kavaratti
# Processing Record 41 of Set 5 | te kauwhata
# Processing Record 42 of Set 5 | leningradskiy
# Processing Record 43 of Set 5 | orange walk
# Processing Record 44 of Set 5 | paysandu
# Processing Record 45 of Set 5 | labuhan
# Processing Record 46 of Set 5 | labytnangi
# Processing Record 47 of Set 5 | odemira
# Processing Record 48 of Set 5 | san angelo
# Processing Record 49 of Set 5 | wattegama
# Processing Record 50 of Set 5 | kieta
# Processing Record 1 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 6 | marienburg
# Processing Record 3 of Set 6 | pochutla
# Processing Record 4 of Set 6 | campo largo
# Processing Record 5 of Set 6 | portobelo
# Processing Record 6 of Set 6 | keighley
# Processing Record 7 of Set 6 | ilulissat
# Processing Record 8 of Set 6 | kitimat
# Processing Record 9 of Set 6 | chifeng
# Processing Record 10 of Set 6 | carutapera
# Processing Record 11 of Set 6 | orlik
# Processing Record 12 of Set 6 | kavieng
# Processing Record 13 of Set 6 | noumea
# Processing Record 14 of Set 6 | ganganagar
# Processing Record 15 of Set 6 | comodoro rivadavia
# Processing Record 16 of Set 6 | salalah
# Processing Record 17 of Set 6 | kibre mengist
# Processing Record 18 of Set 6 | aragats
# Processing Record 19 of Set 6 | urumqi
# Processing Record 20 of Set 6 | ca mau
# Processing Record 21 of Set 6 | mangile
# City not found. Skipping...
# Processing Record 22 of Set 6 | north bend
# Processing Record 23 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 6 | alta floresta
# Processing Record 25 of Set 6 | grobina
# Processing Record 26 of Set 6 | bonthe
# Processing Record 27 of Set 6 | hay river
# Processing Record 28 of Set 6 | linfen
# Processing Record 29 of Set 6 | kushima
# Processing Record 30 of Set 6 | zhovtneve
# Processing Record 31 of Set 6 | suwalki
# Processing Record 32 of Set 6 | pak chong
# Processing Record 33 of Set 6 | souillac
# Processing Record 34 of Set 6 | lom sak
# Processing Record 35 of Set 6 | carson city
# Processing Record 36 of Set 6 | cabedelo
# Processing Record 37 of Set 6 | sur
# Processing Record 38 of Set 6 | ayan
# Processing Record 39 of Set 6 | cabo san lucas
# Processing Record 40 of Set 6 | bonfim
# Processing Record 41 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 42 of Set 6 | nalut
# Processing Record 43 of Set 6 | paralimni
# Processing Record 44 of Set 6 | angleton
# Processing Record 45 of Set 6 | aguimes
# Processing Record 46 of Set 6 | chapais
# Processing Record 47 of Set 6 | shimoda
# Processing Record 48 of Set 6 | kaili
# Processing Record 49 of Set 6 | cao bang
# Processing Record 50 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 7 | kamenka
# Processing Record 2 of Set 7 | diego de almagro
# Processing Record 3 of Set 7 | westport
# Processing Record 4 of Set 7 | beni suef
# Processing Record 5 of Set 7 | catuday
# Processing Record 6 of Set 7 | madimba
# Processing Record 7 of Set 7 | biryusinsk
# Processing Record 8 of Set 7 | rybinsk
# Processing Record 9 of Set 7 | los llanos de aridane
# Processing Record 10 of Set 7 | aktash
# Processing Record 11 of Set 7 | ponta delgada
# Processing Record 12 of Set 7 | severo-kurilsk
# Processing Record 13 of Set 7 | wonthaggi
# Processing Record 14 of Set 7 | gillette
# Processing Record 15 of Set 7 | ajdabiya
# Processing Record 16 of Set 7 | padang
# Processing Record 17 of Set 7 | evensk
# Processing Record 18 of Set 7 | poum
# Processing Record 19 of Set 7 | marzuq
# Processing Record 20 of Set 7 | calvinia
# Processing Record 21 of Set 7 | brandon
# Processing Record 22 of Set 7 | mahebourg
# Processing Record 23 of Set 7 | mattru
# Processing Record 24 of Set 7 | moron
# Processing Record 25 of Set 7 | baena
# Processing Record 26 of Set 7 | aransas pass
# Processing Record 27 of Set 7 | bethel
# Processing Record 28 of Set 7 | semme
# Processing Record 29 of Set 7 | port blair
# Processing Record 30 of Set 7 | jizan
# Processing Record 31 of Set 7 | morant bay
# Processing Record 32 of Set 7 | san matias
# Processing Record 33 of Set 7 | bilma
# Processing Record 34 of Set 7 | barcelona
# Processing Record 35 of Set 7 | sao filipe
# Processing Record 36 of Set 7 | sosnovka
# Processing Record 37 of Set 7 | antofagasta
# Processing Record 38 of Set 7 | octeville
# Processing Record 39 of Set 7 | avera
# Processing Record 40 of Set 7 | rayagada
# Processing Record 41 of Set 7 | ballina
# Processing Record 42 of Set 7 | corinto
# Processing Record 43 of Set 7 | candolim
# Processing Record 44 of Set 7 | mana
# Processing Record 45 of Set 7 | haines junction
# Processing Record 46 of Set 7 | caravelas
# Processing Record 47 of Set 7 | bocanda
# Processing Record 48 of Set 7 | itarema
# Processing Record 49 of Set 7 | new norfolk
# Processing Record 50 of Set 7 | aksarka
# Processing Record 1 of Set 8 | barra do garcas
# Processing Record 2 of Set 8 | nanakuli
# Processing Record 3 of Set 8 | lagoa vermelha
# Processing Record 4 of Set 8 | simpang
# Processing Record 5 of Set 8 | fortuna
# Processing Record 6 of Set 8 | ontario
# Processing Record 7 of Set 8 | acarau
# Processing Record 8 of Set 8 | chokurdakh
# Processing Record 9 of Set 8 | havre-saint-pierre
# Processing Record 10 of Set 8 | melchor de mencos
# Processing Record 11 of Set 8 | veraval
# Processing Record 12 of Set 8 | savannah bight
# Processing Record 13 of Set 8 | zyryanka
# Processing Record 14 of Set 8 | margate
# Processing Record 15 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 8 | loiza
# Processing Record 17 of Set 8 | big rapids
# Processing Record 18 of Set 8 | berga
# Processing Record 19 of Set 8 | bethanien
# Processing Record 20 of Set 8 | hokitika
# Processing Record 21 of Set 8 | iralaya
# Processing Record 22 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 8 | victoria
# Processing Record 24 of Set 8 | napa
# Processing Record 25 of Set 8 | korla
# Processing Record 26 of Set 8 | ponta do sol
# Processing Record 27 of Set 8 | bangkalan
# Processing Record 28 of Set 8 | ixtapa
# Processing Record 29 of Set 8 | padilla
# Processing Record 30 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 8 | ube
# Processing Record 32 of Set 8 | puri
# Processing Record 33 of Set 8 | chernoyerkovskaya
# Processing Record 34 of Set 8 | florida
# Processing Record 35 of Set 8 | impfondo
# Processing Record 36 of Set 8 | labuan
# Processing Record 37 of Set 8 | fare
# Processing Record 38 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 8 | manaure
# Processing Record 40 of Set 8 | grosuplje
# Processing Record 41 of Set 8 | provideniya
# Processing Record 42 of Set 8 | goundi
# Processing Record 43 of Set 8 | chegutu
# Processing Record 44 of Set 8 | lata
# Processing Record 45 of Set 8 | college
# Processing Record 46 of Set 8 | ambilobe
# Processing Record 47 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 8 | simbahan
# Processing Record 49 of Set 8 | codrington
# Processing Record 50 of Set 8 | ranau
# Processing Record 1 of Set 9 | bogande
# Processing Record 2 of Set 9 | cunha
# Processing Record 3 of Set 9 | beyneu
# Processing Record 4 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 9 | kosonsoy
# Processing Record 6 of Set 9 | touho
# Processing Record 7 of Set 9 | gizo
# Processing Record 8 of Set 9 | agua verde
# Processing Record 9 of Set 9 | lamu
# Processing Record 10 of Set 9 | evansville
# Processing Record 11 of Set 9 | tutoia
# Processing Record 12 of Set 9 | oussouye
# Processing Record 13 of Set 9 | magdeburg
# Processing Record 14 of Set 9 | auki
# Processing Record 15 of Set 9 | tefe
# Processing Record 16 of Set 9 | asau
# Processing Record 17 of Set 9 | kidal
# Processing Record 18 of Set 9 | mount gambier
# Processing Record 19 of Set 9 | shitanjing
# Processing Record 20 of Set 9 | kutum
# Processing Record 21 of Set 9 | sayyan
# Processing Record 22 of Set 9 | kattivakkam
# Processing Record 23 of Set 9 | russell
# Processing Record 24 of Set 9 | lumeje
# Processing Record 25 of Set 9 | stekolnyy
# City not found. Skipping...
# Processing Record 26 of Set 9 | turan
# Processing Record 27 of Set 9 | hasaki
# Processing Record 28 of Set 9 | ler
# Processing Record 29 of Set 9 | axim
# Processing Record 30 of Set 9 | okato
# Processing Record 31 of Set 9 | gua musang
# Processing Record 32 of Set 9 | caucaia
# Processing Record 33 of Set 9 | rudbar
# Processing Record 34 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 35 of Set 9 | vanimo
# Processing Record 36 of Set 9 | wiarton
# Processing Record 37 of Set 9 | victoria point
# Processing Record 38 of Set 9 | rio gallegos
# Processing Record 39 of Set 9 | waipawa
# Processing Record 40 of Set 9 | nicoya
# Processing Record 41 of Set 9 | zaplyusye
# City not found. Skipping...
# Processing Record 42 of Set 9 | chikoy
# City not found. Skipping...
# Processing Record 43 of Set 9 | hatsukaichi
# Processing Record 44 of Set 9 | alberton
# Processing Record 45 of Set 9 | tiksi
# Processing Record 46 of Set 9 | pavda
# City not found. Skipping...
# Processing Record 47 of Set 9 | rorvik
# Processing Record 48 of Set 9 | mackay
# Processing Record 49 of Set 9 | luganville
# Processing Record 50 of Set 9 | vilhena
# Processing Record 1 of Set 10 | mayumba
# Processing Record 2 of Set 10 | sovetskiy
# Processing Record 3 of Set 10 | liku
# Processing Record 4 of Set 10 | terra santa
# Processing Record 5 of Set 10 | barroquinha
# Processing Record 6 of Set 10 | toora-khem
# Processing Record 7 of Set 10 | champerico
# Processing Record 8 of Set 10 | kushiro
# Processing Record 9 of Set 10 | port hedland
# Processing Record 10 of Set 10 | sibolga
# Processing Record 11 of Set 10 | kumba
# Processing Record 12 of Set 10 | amahai
# Processing Record 13 of Set 10 | half moon bay
# Processing Record 14 of Set 10 | grindavik
# Processing Record 15 of Set 10 | tete
# Processing Record 16 of Set 10 | mitu
# Processing Record 17 of Set 10 | kismayo
# Processing Record 18 of Set 10 | kirakira
# Processing Record 19 of Set 10 | vicksburg
# Processing Record 20 of Set 10 | hargeysa
# Processing Record 21 of Set 10 | saint anthony
# Processing Record 22 of Set 10 | nanzhou
# Processing Record 23 of Set 10 | abreus
# Processing Record 24 of Set 10 | vila
# Processing Record 25 of Set 10 | san cristobal
# Processing Record 26 of Set 10 | moshkovo
# Processing Record 27 of Set 10 | mulbagal
# Processing Record 28 of Set 10 | mehamn
# Processing Record 29 of Set 10 | balaghat
# Processing Record 30 of Set 10 | ati
# Processing Record 31 of Set 10 | ostrovnoy
# Processing Record 32 of Set 10 | jiroft
# City not found. Skipping...
# Processing Record 33 of Set 10 | bitung
# Processing Record 34 of Set 10 | lasa
# Processing Record 35 of Set 10 | qandahar
# City not found. Skipping...
# Processing Record 36 of Set 10 | winnemucca
# Processing Record 37 of Set 10 | krasnoselkup
# Processing Record 38 of Set 10 | sijunjung
# Processing Record 39 of Set 10 | galveston
# Processing Record 40 of Set 10 | yumen
# Processing Record 41 of Set 10 | fort dix
# Processing Record 42 of Set 10 | novaya ladoga
# Processing Record 43 of Set 10 | santa cruz
# Processing Record 44 of Set 10 | igrim
# Processing Record 45 of Set 10 | altamira
# Processing Record 46 of Set 10 | olinda
# Processing Record 47 of Set 10 | kisangani
# Processing Record 48 of Set 10 | sibenik
# Processing Record 49 of Set 10 | tunxi
# City not found. Skipping...
# Processing Record 50 of Set 10 | cabatuan
# Processing Record 1 of Set 11 | hami
# Processing Record 2 of Set 11 | shiyan
# Processing Record 3 of Set 11 | turukhansk
# Processing Record 4 of Set 11 | puerto morazan
# Processing Record 5 of Set 11 | zaykovo
# Processing Record 6 of Set 11 | anadyr
# Processing Record 7 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 11 | hofn
# Processing Record 9 of Set 11 | badiraguato
# Processing Record 10 of Set 11 | lavrentiya
# Processing Record 11 of Set 11 | pasighat
# Processing Record 12 of Set 11 | marsh harbour
# Processing Record 13 of Set 11 | coahuayana
# Processing Record 14 of Set 11 | karoi
# Processing Record 15 of Set 11 | praia da vitoria
# Processing Record 16 of Set 11 | dunedin
# Processing Record 17 of Set 11 | inirida
# Processing Record 18 of Set 11 | jinchang
# Processing Record 19 of Set 11 | miquelon
# Processing Record 20 of Set 11 | ipixuna
# Processing Record 21 of Set 11 | tsuruga
# Processing Record 22 of Set 11 | raudeberg
# Processing Record 23 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 24 of Set 11 | biak
# Processing Record 25 of Set 11 | asyut
# Processing Record 26 of Set 11 | churapcha
# Processing Record 27 of Set 11 | honiara
# Processing Record 28 of Set 11 | kilmallock
# Processing Record 29 of Set 11 | kailua
# Processing Record 30 of Set 11 | saquena
# Processing Record 31 of Set 11 | halifax
# Processing Record 32 of Set 11 | pisco
# Processing Record 33 of Set 11 | zaysan
# Processing Record 34 of Set 11 | ye
# City not found. Skipping...
# Processing Record 35 of Set 11 | miyakonojo
# Processing Record 36 of Set 11 | visby
# Processing Record 37 of Set 11 | gunjur
# Processing Record 38 of Set 11 | namibe
# Processing Record 39 of Set 11 | bhachau
# Processing Record 40 of Set 11 | ibia
# Processing Record 41 of Set 11 | kruisfontein
# Processing Record 42 of Set 11 | vestmannaeyjar
# Processing Record 43 of Set 11 | coihaique
# Processing Record 44 of Set 11 | woodward
# Processing Record 45 of Set 11 | wakkanai
# Processing Record 46 of Set 11 | saint-francois
# Processing Record 47 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 11 | siavonga
# Processing Record 49 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 50 of Set 11 | vysokogornyy
# Processing Record 1 of Set 12 | lincoln
# Processing Record 2 of Set 12 | praya
# Processing Record 3 of Set 12 | bereda
# Processing Record 4 of Set 12 | sidi ali
# Processing Record 5 of Set 12 | narrabri
# Processing Record 6 of Set 12 | marrakesh
# Processing Record 7 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 8 of Set 12 | mazagao
# Processing Record 9 of Set 12 | ierapetra
# Processing Record 10 of Set 12 | leh
# Processing Record 11 of Set 12 | belmonte
# Processing Record 12 of Set 12 | nova ushytsya
# Processing Record 13 of Set 12 | newport
# Processing Record 14 of Set 12 | kautokeino
# Processing Record 15 of Set 12 | iwaki
# Processing Record 16 of Set 12 | portland
# Processing Record 17 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 12 | kingman
# Processing Record 19 of Set 12 | deputatskiy
# Processing Record 20 of Set 12 | iquique
# Processing Record 21 of Set 12 | mirabad
# Processing Record 22 of Set 12 | araruna
# Processing Record 23 of Set 12 | hovd
# Processing Record 24 of Set 12 | chiang khong
# Processing Record 25 of Set 12 | lazaro cardenas
# Processing Record 26 of Set 12 | baruun-urt
# Processing Record 27 of Set 12 | tigre
# Processing Record 28 of Set 12 | qui nhon
# Processing Record 29 of Set 12 | vestmanna
# Processing Record 30 of Set 12 | latung
# Processing Record 31 of Set 12 | port lincoln
# Processing Record 32 of Set 12 | japura
# Processing Record 33 of Set 12 | kudahuvadhoo
# Processing Record 34 of Set 12 | kahului
# Processing Record 35 of Set 12 | treinta y tres
# Processing Record 36 of Set 12 | lanigan
# Processing Record 37 of Set 12 | langxiang
# Processing Record 38 of Set 12 | gatton
# Processing Record 39 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 40 of Set 12 | boissevain
# Processing Record 41 of Set 12 | vryburg
# Processing Record 42 of Set 12 | durusu
# Processing Record 43 of Set 12 | erenhot
# Processing Record 44 of Set 12 | babstovo
# Processing Record 45 of Set 12 | baykit
# Processing Record 46 of Set 12 | luorong
# Processing Record 47 of Set 12 | klaksvik
# Processing Record 48 of Set 12 | sao lourenco do sul
# Processing Record 49 of Set 12 | campo verde
# Processing Record 50 of Set 12 | ust-kuyga
# Processing Record 1 of Set 13 | conde
# Processing Record 2 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 13 | shubarshi
# Processing Record 4 of Set 13 | moscow
# Processing Record 5 of Set 13 | boa vista
# Processing Record 6 of Set 13 | tezu
# Processing Record 7 of Set 13 | maracacume
# Processing Record 8 of Set 13 | vredendal
# Processing Record 9 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 13 | husavik
# Processing Record 11 of Set 13 | tabou
# Processing Record 12 of Set 13 | mega
# Processing Record 13 of Set 13 | senmonorom
# City not found. Skipping...
# Processing Record 14 of Set 13 | sinnamary
# Processing Record 15 of Set 13 | ferrol
# Processing Record 16 of Set 13 | popondetta
# Processing Record 17 of Set 13 | gat
# Processing Record 18 of Set 13 | lagoa
# Processing Record 19 of Set 13 | iracoubo
# Processing Record 20 of Set 13 | sorland
# Processing Record 21 of Set 13 | saquarema
# Processing Record 22 of Set 13 | robertson
# Processing Record 23 of Set 13 | fort nelson
# Processing Record 24 of Set 13 | bambous virieux
# Processing Record 25 of Set 13 | tambura
# Processing Record 26 of Set 13 | odweyne
# Processing Record 27 of Set 13 | rawah
# Processing Record 28 of Set 13 | makakilo city
# Processing Record 29 of Set 13 | montana
# Processing Record 30 of Set 13 | san francisco del mar
# Processing Record 31 of Set 13 | muros
# Processing Record 32 of Set 13 | nsanje
# Processing Record 33 of Set 13 | maniitsoq
# Processing Record 34 of Set 13 | gurgaon
# Processing Record 35 of Set 13 | norsup
# Processing Record 36 of Set 13 | mozarlandia
# Processing Record 37 of Set 13 | ahipara
# Processing Record 38 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 39 of Set 13 | havelock
# Processing Record 40 of Set 13 | maragogi
# Processing Record 41 of Set 13 | usa river
# Processing Record 42 of Set 13 | dukat
# Processing Record 43 of Set 13 | asfi
# Processing Record 44 of Set 13 | florence
# Processing Record 45 of Set 13 | juneau
# Processing Record 46 of Set 13 | quatre cocos
# Processing Record 47 of Set 13 | boende
# Processing Record 48 of Set 13 | santa marta
# Processing Record 49 of Set 13 | bathsheba
# Processing Record 50 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 14 | richards bay
# Processing Record 2 of Set 14 | adrar
# Processing Record 3 of Set 14 | sao felix do xingu
# Processing Record 4 of Set 14 | flin flon
# Processing Record 5 of Set 14 | punta alta
# Processing Record 6 of Set 14 | pottsville
# Processing Record 7 of Set 14 | fergus falls
# Processing Record 8 of Set 14 | oksfjord
# Processing Record 9 of Set 14 | almazar
# Processing Record 10 of Set 14 | kuching
# Processing Record 11 of Set 14 | itaituba
# Processing Record 12 of Set 14 | ronneby
# Processing Record 13 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 14 of Set 14 | jacksonville
# Processing Record 15 of Set 14 | ancud
# Processing Record 16 of Set 14 | samarai
# Processing Record 17 of Set 14 | atambua
# Processing Record 18 of Set 14 | kachug
# Processing Record 19 of Set 14 | itamaraju
# Processing Record 20 of Set 14 | zabol
# Processing Record 21 of Set 14 | capreol
# Processing Record 22 of Set 14 | cayenne
# Processing Record 23 of Set 14 | jiujiang
# Processing Record 24 of Set 14 | itupiranga
# Processing Record 25 of Set 14 | yar-sale
# Processing Record 26 of Set 14 | bontang
# Processing Record 27 of Set 14 | tottori
# Processing Record 28 of Set 14 | manteca
# Processing Record 29 of Set 14 | tatarbunary
# Processing Record 30 of Set 14 | plettenberg bay
# Processing Record 31 of Set 14 | tamiahua
# Processing Record 32 of Set 14 | srednekolymsk
# Processing Record 33 of Set 14 | yuli
# Processing Record 34 of Set 14 | orebro
# Processing Record 35 of Set 14 | pacific grove
# Processing Record 36 of Set 14 | camacha
# Processing Record 37 of Set 14 | tacoronte
# Processing Record 38 of Set 14 | wahiawa
# Processing Record 39 of Set 14 | emirdag
# Processing Record 40 of Set 14 | shirokiy
# Processing Record 41 of Set 14 | taoudenni
# Processing Record 42 of Set 14 | puerto asis
# Processing Record 43 of Set 14 | sulina
# Processing Record 44 of Set 14 | sao joao da barra
# Processing Record 45 of Set 14 | santa isabel
# Processing Record 46 of Set 14 | afua
# Processing Record 47 of Set 14 | cuiluan
# Processing Record 48 of Set 14 | porbandar
# Processing Record 49 of Set 14 | nettuno
# Processing Record 50 of Set 14 | tomatlan
# Processing Record 1 of Set 15 | lagunas
# Processing Record 2 of Set 15 | stornoway
# Processing Record 3 of Set 15 | tiarei
# Processing Record 4 of Set 15 | hervey bay
# Processing Record 5 of Set 15 | salekhard
# Processing Record 6 of Set 15 | abalak
# Processing Record 7 of Set 15 | vostochnyy
# Processing Record 8 of Set 15 | kununurra
# Processing Record 9 of Set 15 | yichang
# Processing Record 10 of Set 15 | valenca do piaui
# Processing Record 11 of Set 15 | atar
# Processing Record 12 of Set 15 | colares
# Processing Record 13 of Set 15 | calama
# Processing Record 14 of Set 15 | naantali
# Processing Record 15 of Set 15 | camocim
# Processing Record 16 of Set 15 | atyashevo
# Processing Record 17 of Set 15 | farafangana
# Processing Record 18 of Set 15 | yarmouth
# Processing Record 19 of Set 15 | ocampo
# Processing Record 20 of Set 15 | dubbo
# Processing Record 21 of Set 15 | chilca
# Processing Record 22 of Set 15 | batsfjord
# Processing Record 23 of Set 15 | narasapur
# Processing Record 24 of Set 15 | maumere
# Processing Record 25 of Set 15 | bilibino
# Processing Record 26 of Set 15 | braslav
# City not found. Skipping...
# Processing Record 27 of Set 15 | nara
# Processing Record 28 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 29 of Set 15 | pyapon
# Processing Record 30 of Set 15 | aden
# Processing Record 31 of Set 15 | qeshm
# Processing Record 32 of Set 15 | tucuman
# Processing Record 33 of Set 15 | shibarghan
# City not found. Skipping...
# Processing Record 34 of Set 15 | ratnagiri
# Processing Record 35 of Set 15 | si satchanalai
# Processing Record 36 of Set 15 | novyy urengoy
# Processing Record 37 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 15 | chernyshevskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 677

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Narsaq  60.9167  -46.0500     48.42        88         100
# 1         Rikitea -23.1203 -134.9692     73.31        72          91
# 2           Atasu  48.6814   71.6433     61.03        81          94
# 3       Busselton -33.6500  115.3333     51.87        83          64
# 4           Vaini -21.2000 -175.2000     78.96        94          75
# 5  Port Elizabeth -33.9180   25.5701     55.69        92           0
# 6      Bredasdorp -34.5322   20.0403     50.97        95          86
# 7        Thompson  55.7435  -97.8558     73.11        30          41
# 8         Ushuaia -54.8000  -68.3000     38.86        87          75
# 9        Tasiilaq  65.6145  -37.6368     41.16        77         100
#
#    Wind Speed Country Current Description
# 0        6.11      GL       moderate rain
# 1       21.14      PF     overcast clouds
# 2       10.00      KZ     overcast clouds
# 3        5.21      AU       broken clouds
# 4       16.11      TO       broken clouds
# 5        4.61      ZA           clear sky
# 6        3.98      ZA     overcast clouds
# 7        5.95      CA    scattered clouds
# 8       18.41      AR          light rain
# 9        6.22      GL     overcast clouds

# %%
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Narsaq      GL  60.9167  -46.0500     48.42        88         100
# 1         Rikitea      PF -23.1203 -134.9692     73.31        72          91
# 2           Atasu      KZ  48.6814   71.6433     61.03        81          94
# 3       Busselton      AU -33.6500  115.3333     51.87        83          64
# 4           Vaini      TO -21.2000 -175.2000     78.96        94          75
# 5  Port Elizabeth      ZA -33.9180   25.5701     55.69        92           0
# 6      Bredasdorp      ZA -34.5322   20.0403     50.97        95          86
# 7        Thompson      CA  55.7435  -97.8558     73.11        30          41
# 8         Ushuaia      AR -54.8000  -68.3000     38.86        87          75
# 9        Tasiilaq      GL  65.6145  -37.6368     41.16        77         100
#
#    Wind Speed Current Description
# 0        6.11       moderate rain
# 1       21.14     overcast clouds
# 2       10.00     overcast clouds
# 3        5.21       broken clouds
# 4       16.11       broken clouds
# 5        4.61           clear sky
# 6        3.98     overcast clouds
# 7        5.95    scattered clouds
# 8       18.41          light rain
# 9        6.22     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
